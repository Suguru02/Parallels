# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
threads = np.array([1, 2, 4, 7, 8, 16, 20, 40])
gain1 = np.array([0.878019, 1.67524, 3.34507, 5.60318, 6.78945, 12.3393, 14.1781, 13.7157]) 
gain2 = np.array([0.783215, 1.59065, 3.11605, 5.34779, 6.53414, 11.8363, 14.4294, 14.8222]) 
pret_ar = np.array([1.0, 2.0, 4.0, 7.0, 8.0, 16.0, 20.0, 40.0])

# Построение графиков
plt.plot(threads, pret_ar,  'o-', color='black', linewidth=2, markersize=5, label='Ideal Speedup (S = p)')
plt.plot(threads, gain1, 'o-', color='blue', linewidth=2, markersize=5, label='N = 20000')
plt.plot(threads, gain2, 'o-', color='red', linewidth=2, markersize=5, label='N = 40000')

# Подписи и оформление
plt.xlabel('Number of Threads (p)', fontsize=12)
plt.ylabel('Speedup (S)', fontsize=12)
plt.title('Task 1', fontsize=14, fontweight='bold')
plt.legend(fontsize=11, loc='upper left')
plt.grid(True, alpha=0.3)

for i, txt in enumerate(gain1):
    plt.annotate(f'{txt:.1f}', (threads[i], gain1[i]), 
                xytext=(5, -10), textcoords='offset points', fontsize=8, color='blue')
    
for i, txt in enumerate(gain2):
    plt.annotate(f'{txt:.1f}', (threads[i], gain2[i]), 
                xytext=(5, -20), textcoords='offset points', fontsize=8, color='red')

for i, txt in enumerate(pret_ar):
    plt.annotate(f'{txt:.1f}', (threads[i], pret_ar[i]), 
                xytext=(5, 20), textcoords='offset points', fontsize=8, color='black')


plt.show()

# %%
threads = np.array([1, 2, 4, 7, 8, 16, 20, 40])
gain1 = np.array([1.00646, 1.99525, 3.97251, 6.86081, 7.82453, 13.9453, 17.088, 25.874]) 
gain2 = np.array([0.992393, 1.97607, 3.94808, 6.80881, 7.80153, 14.8414, 17.6105, 25.6524]) 
pret_ar = np.array([1.0, 2.0, 4.0, 7.0, 8.0, 16.0, 20.0, 40.0])

# Построение графиков
plt.plot(threads, pret_ar,  'o-', color='black', linewidth=2, markersize=5, label='Ideal Speedup (S = p)')
plt.plot(threads, gain1, 'o-', color='blue', linewidth=2, markersize=5, label='NSteps = 40000000')
plt.plot(threads, gain2, 'o-', color='red', linewidth=2, markersize=5, label='NSteps = 80000000')

# Подписи и оформление
plt.xlabel('Number of Threads (p)', fontsize=12)
plt.ylabel('Speedup (S)', fontsize=12)
plt.title('Task 2', fontsize=14, fontweight='bold')
plt.legend(fontsize=11, loc='upper left')
plt.grid(True, alpha=0.3)

for i, txt in enumerate(gain1):
    plt.annotate(f'{txt:.1f}', (threads[i], gain1[i]), 
                xytext=(5, -10), textcoords='offset points', fontsize=8, color='blue')
    
for i, txt in enumerate(gain2):
    plt.annotate(f'{txt:.1f}', (threads[i], gain2[i]), 
                xytext=(5, -20), textcoords='offset points', fontsize=8, color='red')

for i, txt in enumerate(pret_ar):
    plt.annotate(f'{txt:.1f}', (threads[i], pret_ar[i]), 
                xytext=(5, 20), textcoords='offset points', fontsize=8, color='black')


plt.show()

# %%
threads = np.array([2, 4, 7, 8, 16, 20, 40])
gain1 = np.array([1.739065, 3.477029, 5.829244, 6.520396, 5.663571, 6.035458, 6.690147]) 
gain2 = np.array([2.030730, 3.930508, 6.679373, 7.361313, 6.040612, 6.264260, 6.945415]) 
pret_ar = np.array([2.0, 4.0, 7.0, 8.0, 16.0, 20.0, 40.0])

# Построение графиков
plt.plot(threads, pret_ar,  'o-', color='black', linewidth=2, markersize=5, label='Ideal Speedup (S = p)')
plt.plot(threads, gain1, 'o-', color='blue', linewidth=2, markersize=5, label='N = V1')
plt.plot(threads, gain2, 'o-', color='red', linewidth=2, markersize=5, label='N = V2')

# Подписи и оформление
plt.xlabel('Number of Threads (p)', fontsize=12)
plt.ylabel('Speedup (S)', fontsize=12)
plt.title('Task 3', fontsize=14, fontweight='bold')
plt.legend(fontsize=11, loc='upper left')
plt.grid(True, alpha=0.3)

for i, txt in enumerate(gain1):
    plt.annotate(f'{txt:.1f}', (threads[i], gain1[i]), 
                xytext=(5, -10), textcoords='offset points', fontsize=8, color='blue')
    
for i, txt in enumerate(gain2):
    plt.annotate(f'{txt:.1f}', (threads[i], gain2[i]), 
                xytext=(5, -20), textcoords='offset points', fontsize=8, color='red')

for i, txt in enumerate(pret_ar):
    plt.annotate(f'{txt:.1f}', (threads[i], pret_ar[i]), 
                xytext=(5, 20), textcoords='offset points', fontsize=8, color='black')


plt.show()
